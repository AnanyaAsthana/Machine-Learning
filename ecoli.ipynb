# %% [markdown]
# <a href="https://colab.research.google.com/github/AnanyaAsthana/Machine-Learning/blob/main/ecoli.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import urllib.request
import zipfile

from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

# %%
url = "https://sci2s.ugr.es/keel/dataset/data/classification/ecoli-5-fold.zip"
zip_name = "ecoli-5-fold.zip"

urllib.request.urlretrieve(url, zip_name)
print("Ecoli 5-fold dataset downloaded.")
# Out:
# Ecoli 5-fold dataset downloaded.

# %%
with zipfile.ZipFile(zip_name, 'r') as zip_ref:
    zip_ref.extractall("ecoli")

print("Dataset extracted.")
# Out:
# Dataset extracted.

# %%
def load_keel_dat(path):
    data = []
    with open(path, "r") as f:
        for line in f:
            if not line.startswith("@") and line.strip():
                data.append(line.strip().split(","))
    return pd.DataFrame(data)

# %%
folds = [
    ("ecoli/ecoli-5-1tra.dat", "ecoli/ecoli-5-1tst.dat"),
    ("ecoli/ecoli-5-2tra.dat", "ecoli/ecoli-5-2tst.dat"),
    ("ecoli/ecoli-5-3tra.dat", "ecoli/ecoli-5-3tst.dat"),
    ("ecoli/ecoli-5-4tra.dat", "ecoli/ecoli-5-4tst.dat"),
    ("ecoli/ecoli-5-5tra.dat", "ecoli/ecoli-5-5tst.dat"),
]

# %%
k_values = [1, 3, 5, 7, 9]
k_accuracy = {k: [] for k in k_values}

for fold_no, (train_path, test_path) in enumerate(folds, 1):
    print(f"\nFold {fold_no}")

    train_df = load_keel_dat(train_path)
    test_df = load_keel_dat(test_path)

    X_train = train_df.iloc[:, :-1].astype(float)
    y_train = train_df.iloc[:, -1]

    X_test = test_df.iloc[:, :-1].astype(float)
    y_test = test_df.iloc[:, -1]

    for k in k_values:
        model = Pipeline([
            ("scaler", StandardScaler()),
            ("knn", KNeighborsClassifier(n_neighbors=k))
        ])

        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        acc = accuracy_score(y_test, y_pred)
        k_accuracy[k].append(acc)

        print(f"  k = {k} → Accuracy = {acc:.4f}")
# Out:
# Fold 1
#   k = 1 → Accuracy = 0.7206
#   k = 3 → Accuracy = 0.7794
#   k = 5 → Accuracy = 0.7647
#   k = 7 → Accuracy = 0.7647
#   k = 9 → Accuracy = 0.7500
#
# Fold 2
#   k = 1 → Accuracy = 0.8507
#   k = 3 → Accuracy = 0.7910
#   k = 5 → Accuracy = 0.7910
#   k = 7 → Accuracy = 0.7761
#   k = 9 → Accuracy = 0.8060
#
# Fold 3
#   k = 1 → Accuracy = 0.7015
#   k = 3 → Accuracy = 0.7612
#   k = 5 → Accuracy = 0.8060
#   k = 7 → Accuracy = 0.8060
#   k = 9 → Accuracy = 0.7910
#
# Fold 4
#   k = 1 → Accuracy = 0.8657
#   k = 3 → Accuracy = 0.8507
#   k = 5 → Accuracy = 0.8806
#   k = 7 → Accuracy = 0.8657
#   k = 9 → Accuracy = 0.8358
#
# Fold 5
#   k = 1 → Accuracy = 0.8209
#   k = 3 → Accuracy = 0.8358
#   k = 5 → Accuracy = 0.8358
#   k = 7 → Accuracy = 0.8507
#   k = 9 → Accuracy = 0.8358

# %%
print("\nAverage Accuracy Across 5 Folds:")

best_k = None
best_mean_acc = -1

for k in k_values:
    mean_acc = np.mean(k_accuracy[k])
    print(f"k = {k}, Mean Accuracy = {mean_acc:.4f}")

    if mean_acc > best_mean_acc:
        best_mean_acc = mean_acc
        best_k = k

print("\n✅ Optimal value of k:", best_k)
print("✅ Maximum mean accuracy:", best_mean_acc)
# Out:
# Average Accuracy Across 5 Folds:
# k = 1, Mean Accuracy = 0.7919
# k = 3, Mean Accuracy = 0.8036
# k = 5, Mean Accuracy = 0.8156
# k = 7, Mean Accuracy = 0.8126
# k = 9, Mean Accuracy = 0.8037
#
# ✅ Optimal value of k: 5
# ✅ Maximum mean accuracy: 0.8156277436347674
